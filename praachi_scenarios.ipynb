# %% [markdown]
# ## Scenario 1 — Talking About Money (and other sensitive topics)
# Use HeyRoommate to bring up shared expenses and payment reminders in a way that feels neutral and personalized to each roommate’s tone preferences.

# %% [markdown]
# #### **Short Description**
# Rephrasing a money-related message so it sounds calm, transparent, and fair — not passive-aggressive or guilt-trippy.

# %% [markdown]
# #### **Narrative of Scenario**
# Nina and Sam share groceries and utilities, but conversations about splitting costs tend to get awkward or feel passive aggressive. In the past, Sam’s short, direct reminders have sounded cold, while Nina’s long explanations sometimes made Sam feel nagged. After a few tense exchanges, **HeyRoommate flags “financial discussions”** as a **high-sensitivity topic** for them.
#
# When Sam notices Nina hasn’t paid her half of the electric bill, he drafts a message that says, `“Can you Venmo me for your part of the bill? It’s been a week.”` HeyRoommate detects that this could come off as frustrated and suggests a gentler rewrite by adjusting Sam’s tone slider.* The app generates three options, one of which reads, `“Hey, just a quick reminder about the electric bill from last week — no rush, just making sure you saw it!”`
#
# Sam picks that version and sends it through the app. Once Nina replies positively and sends payment, HeyRoommate logs the outcome as a **positive resolution** and slightly adjusts Sam’s tone profile to reinforce that softer phrasing leads to better results with Nina.

# %% [markdown]
# #### **Step-by-Step Breakdown**
#
# ```mermaid
# sequenceDiagram
# participant Sam
# participant HeyRoommate
# participant Nina
#
# Sam->>HeyRoommate: Opens app and selects “Bill Reminder” topic
# HeyRoommate->>Sam: Retrieves past message outcomes tagged “money/expenses”
# Sam->>HeyRoommate: Drafts message + sets tone slider (“neutral + efficient”)
# HeyRoommate->>Sam: Generates 3 reworded options + rationale + confidence score
# Sam->>HeyRoommate: Chooses one and sends via in-app DM
# HeyRoommate->>Nina: Delivers phrased message in Nina’s tone preference (warm + brief)
# Nina->>HeyRoommate: Replies + sends payment confirmation
# HeyRoommate->>Sam: Summarizes outcome + updates tone effectiveness data

# %% [markdown]
# #### **Data Description**
# ##### Needed:
# * User draft: Sam’s initial message text
# * Tone preferences: Sam (direct + efficient), Nina (warm + reassuring)
# * Topic tag: “Expenses” (auto-detected from text or manual selection)
# * Context snippets: previous payment reminders and outcomes
# * Delivery settings: in-app message or text relay
#
# ##### Created:
# * Rewritten message options with tone rationales
# * Confidence and clarity scores for each rewrite
# * Outcome log: delivery status, timestamp, reply sentiment, payment confirmed
# * Updated preference weights (reinforcement for what tone works best)
# * Feedback data for continuous tone-effectiveness learning

# %% [markdown]
# #### **Evaluation**
# ##### Success Criteria:
# * Message tone rated clear and respectful by both parties
# * Payment task marked as completed within 24 hours
# * Positive or neutral sentiment in response message
# * Sam marks the tone “helpful” or “reduced tension”
# ##### Complications & Error Handling:
# * If ambiguity: app prompts “Which bill?”
# * If over-softed tone: detected by no response, next reminder becomes firmer
# * If Adversarial response: detects sarcasm/tension, flags for review
# * Privacy issues? Stores only metadata (sentiment + tone success), not full text

# %% [markdown]
# ## Scenario 2 – Consitent Cleaning Schedule
# Use HeyRoommate to make shared chores easier by automatically dividing and reminding each roommate about their tasks in a fair and non-annoying way.

# %% [markdown]
# #### **Short Description**
# Auto-creating a recurring cleaning checklist that divides chores evenly and reminds each roommate in their preferred tone and timing.

# %% [markdown]
# #### **Narrative of Scenario**
# Sam and Nina have had repeated arguments about cleaning responsibilities — mostly because reminders kept coming off as passive-aggressive or unfair. After noticing this pattern in their past messages and feedback, **HeyRoommate** steps in and suggests turning on its **Task Divider** feature.
#
# The feature creates a shared weekly cleaning checklist based on what they’ve already agreed to (for example, alternating bathroom duty). Each person gets reminders written in their own communication style — Sam’s are short and to the point, while Nina’s are softer and more encouraging. HeyRoommate also learns over time when each roommate responds best (for example, Nina in the mornings) and automatically adjusts when to send prompts.
#
# When it’s Nina’s turn, she gets a reminder like `“It’s your week for the bathroom — you’ve got this.”` Once she marks it complete, the app updates the shared log for both of them so Sam doesn’t have to remind her manually. This helps them stay accountable and avoid repeating the same argument every week.

# %% [markdown]
# #### **Step-by-Step Breakdown**
#
# ```mermaid
# sequenceDiagram
# participant Sam
# participant HeyRoommate
# participant Nina
#
# HeyRoommate->>Sam: Suggests “Task Divider” after noticing repeated cleaning conflicts
# Sam->>HeyRoommate: Accepts and inputs frequency + rotation preferences
# HeyRoommate->>Nina: Sends friendly invite phrased in Nina’s tone (gentle + inclusive)
# Nina->>HeyRoommate: Confirms and sets preferred reminder tone/time
# HeyRoommate->>HeyRoommate: Generates shared cleaning checklist (bathroom, kitchen, trash etc.)
# HeyRoommate->>Nina: Sends reminder “It’s your week for the bathroom — you’ve got this 💪”
# Nina->>HeyRoommate: Marks task complete
# HeyRoommate->>Sam: Updates shared log + sends brief progress summary
# HeyRoommate->>HeyRoommate: Learns what timing/tone works best → updates future prompts

# %% [markdown]
# #### **Data Description**
# ##### Needed:
# * User profiles: tone preferences (Sam = direct, Nina = gentle/supportive)
# * Task info: recurring chores, rotation schedule, and timing
# * Interaction history: prior cleaning disagreements flagged by the app
# * Reminder settings: preferred tone, delivery channel, and notification timing
# * How provided: pulled from app history + user inputs at setup
#
# ##### Created:
# * Shared rotating cleaning checklist
# * Tone-matched reminder messages
# * Completion log (timestamp, task, person, optional emoji feedback)
# * Updated roommate preference data (reinforcement for what phrasing/timing works)
# * Conflict-reduction stats (tracking fewer “negative tone” cleaning messages)

# %% [markdown]
# #### Evaluation
# ##### Success Criteria:
# * Both roommates say reminders feel fair and neutral
# * At least 90 % of chores completed across a month
# * No flagged “negative tone” messages
# * Users rate the feature as “helpful” or “reduced tension”
# ##### Complications & Error Handling:
# * If confusion about rotation → HeyRoommate clarifies (“Want to swap weeks?”)
# * If no response → sends soft follow-up 24 hours later
# * If tone mismatch → adjusts to less firm tone next time
# * If uneven workload → suggests schedule rebalancing
# * Privacy → data stored locally; message logs anonymized
